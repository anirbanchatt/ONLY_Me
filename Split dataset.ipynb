# %% [markdown]
# ### Install split folders library

# %%
pip install split-folders

# %% [markdown]
# ## Split dataset

# %%
import splitfolders

# %%
splitfolders.ratio('dataset/finalKeyFrames', output="dataset p2", seed=1337, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 7717 files [00:35, 215.49 files/s]

# %%
splitfolders.ratio('new dataset/finalKeyFrames', output="new dataset/new dataset p2", seed=1337, ratio=(.8, 0.1,0.1))
# Out:
# Copying files: 0 files [00:00, ? files/s]
#
# Copying files: 1 files [00:00,  4.34 files/s]
#
# Copying files: 118 files [00:00, 449.40 files/s]
#
# Copying files: 240 files [00:00, 719.24 files/s]
#
# Copying files: 364 files [00:00, 891.24 files/s]
#
# Copying files: 487 files [00:00, 999.68 files/s]
#
# Copying files: 609 files [00:00, 1065.94 files/s]
#
# Copying files: 734 files [00:00, 1120.46 files/s]
#
# Copying files: 858 files [00:00, 1154.51 files/s]
#
# Copying files: 981 files [00:01, 1174.85 files/s]
#
# Copying files: 1103 files [00:01, 1186.00 files/s]
#
# Copying files: 1224 files [00:01, 1190.47 files/s]
#
# Copying files: 1345 files [00:01, 1182.78 files/s]
#
# Copying files: 1468 files [00:01, 1194.13 files/s]
#
# Copying files: 1589 files [00:01, 1044.90 files/s]
#
# Copying files: 1702 files [00:01, 1065.73 files/s]
#
# Copying files: 1821 files [00:01, 1098.20 files/s]
#
# Copying files: 1937 files [00:01, 1113.34 files/s]
#
# ...
